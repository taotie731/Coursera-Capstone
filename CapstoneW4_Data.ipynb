# %% [markdown]
# # Data

# %% [markdown]
# ## Data sources

# %% [markdown]
# ### Source 1:
# New York neighborhood data from here
# https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json

# %%
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# ### Source 2:
# FourSquare API data with venues of all neighborhood data in New York

# %%
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0  Battery Park City           Coffee Shop                  Park
# 1      Carnegie Hill           Coffee Shop                  Café
# 2     Central Harlem    Seafood Restaurant   American Restaurant
# 3            Chelsea           Coffee Shop                Bakery
# 4          Chinatown    Chinese Restaurant                Bakery
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                 Hotel        Clothing Store         Memorial Site
# 1                   Bar           Pizza Place     French Restaurant
# 2  Gym / Fitness Center    Chinese Restaurant     French Restaurant
# 3           Art Gallery   American Restaurant     French Restaurant
# 4          Cocktail Bar   American Restaurant          Optical Shop
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                   Gym         Boat or Ferry            Playground
# ...

# %% [markdown]
# ## Explanation
#
# Using the neightborhood data together with FourSquare API, I will cluster the neightborhoods and find out the best neighborhood for restuarants and offices.
